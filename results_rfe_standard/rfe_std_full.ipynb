# %%
import pandas as pd
from IPython.display import display

# --- show full column content ---
pd.set_option('display.max_colwidth', None)
pd.set_option('display.max_rows', None)

file_path = 'test_results.csv'

# Load the CSV file into a pandas DataFrame
try:
    results_df = pd.read_csv(file_path)
    print("--- Test Set Performance (Standard Scoring) ---")
    display(results_df)

except FileNotFoundError:
    print(f"Error: The file was not found at '{file_path}'")
    print("Please make sure the notebook is in the correct parent directory.")

    #6 for MoP
    #7 for MoE
# Out:
# --- Test Set Performance (Standard Scoring) ---
#   Dataset    Scoring Model  Accuracy   ROC-AUC  Precision    Recall  F1 Score  \
# 0    Test   accuracy   MoP  0.737410  0.806522   0.716129  0.792857  0.752542
# 1    Test   accuracy   MoE  0.730216  0.809576   0.744361  0.707143  0.725275
# 2    Test         f1   MoP  0.744604  0.802795   0.741259  0.757143  0.749117
# 3    Test         f1   MoE  0.730216  0.795859   0.701863  0.807143  0.750831
# 4    Test  precision   MoP  0.755396  0.810792   0.760870  0.750000  0.755396
# 5    Test  precision   MoE  0.733813  0.832143   0.714286  0.785714  0.748299
# 6    Test    roc_auc   MoP  0.755396  0.819177   0.764706  0.742857  0.753623
# 7    Test    roc_auc   MoE  0.737410  0.800932   0.751880  0.714286  0.732601
#
#    Cohen Kappa  n_features  \
# 0     0.474385          19
# 1     0.460599          26
# 2     0.489103          64
# 3     0.459817          14
# 4     0.510817          55
# 5     0.467212          48
# 6     0.510867          27
# 7     0.474983          31
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       features
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               ['Age at recruitment', 'Year of birth', "Standard PRS for alzheimer's disease (AD)", 'Has_Heart_attack', 'Has_Stroke', 'Has_High_blood_pressure', 'Sleep duration | Instance 0', 'Mean time to correctly identify matches | Instance 0', 'Fluid intelligence score | Instance 0', 'Triglycerides | Instance 0', 'Creatinine | Instance 0', 'Diabetes_Status_No', 'Diabetes_Status_Yes', 'Smoking status | Instance 0_Current', 'Alcohol drinker status | Instance 0_Previous', 'Alcohol intake frequency. | Instance 0_Never', 'Bipolar and major depression status | Instance 0_No Bipolar or Depression', 'Worrier / anxious feelings | Instance 0_Prefer not to answer', 'Gate_speed_slow']
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          ['Age at recruitment', 'Year of birth', "Standard PRS for alzheimer's disease (AD)", 'Townsend deprivation index at recruitment', 'Number in household | Instance 0', 'Has_Angina', 'Has_High_blood_pressure', 'Cholesterol | Instance 0', 'Creatinine | Instance 0', 'Computed_RSA_ln_ms2_Inst0', 'Average_RR_ms_Inst0', 'Sex_Male', 'Diabetes_Status_Do not know', 'Diabetes_Status_No', 'Smoking status | Instance 0_Current', 'Smoking status | Instance 0_Prefer not to answer', 'Smoking status | Instance 0_Previous', 'Alcohol drinker status | Instance 0_Current', 'Alcohol intake frequency. | Instance 0_Never', 'Alcohol intake frequency. | Instance 0_Once or twice a week', 'Alcohol intake frequency. | Instance 0_One to three times a month', 'Alcohol intake frequency. | Instance 0_Three or four times a week', 'Bipolar and major depression status | Instance 0_Bipolar I Disorder', 'Bipolar and major depression status | Instance 0_No Bipolar or Depression', 'Worrier / anxious feelings | Instance 0_Do not know', 'Hand grip strength | Instance 0']
# 2  ['Age at recruitment', 'Year of birth', "Standard PRS for alzheimer's disease (AD)", 'Townsend deprivation index at recruitment', 'Number in household | Instance 0', 'Has_Heart_attack', 'Has_Angina', 'Has_Stroke', 'Has_High_blood_pressure', 'Has_Any_Vascular_Heart_Problem', 'Sleep duration | Instance 0', 'Number of days/week of vigorous physical activity 10+ minutes | Instance 0', 'Number of days/week of moderate physical activity 10+ minutes | Instance 0', 'Mean time to correctly identify matches | Instance 0', 'Fluid intelligence score | Instance 0', 'Cholesterol | Instance 0', 'Triglycerides | Instance 0', 'C-reactive protein | Instance 0', 'Glucose | Instance 0', 'Glycated haemoglobin (HbA1c) | Instance 0', 'Creatinine | Instance 0', 'Computed_RSA_ln_ms2_Inst0', 'Average_HR_bpm_Inst0', 'Average_RR_ms_Inst0', 'Pretest_RSA_ln_ms2_Inst0', 'Activity_RSA_ln_ms2_Inst0', 'Recovery_RSA_ln_ms2_Inst0', 'Avg_HeartPeriod_ms_Inst0', 'Sex_Female', 'Sex_Male', 'Diabetes_Status_Do not know', 'Diabetes_Status_No', 'Diabetes_Status_Prefer not to answer', 'Diabetes_Status_Yes', 'Smoking status | Instance 0_Current', 'Smoking status | Instance 0_Never', 'Smoking status | Instance 0_Prefer not to answer', 'Smoking status | Instance 0_Previous', 'Alcohol drinker status | Instance 0_Current', 'Alcohol drinker status | Instance 0_Never', 'Alcohol drinker status | Instance 0_Prefer not to answer', 'Alcohol drinker status | Instance 0_Previous', 'Alcohol intake frequency. | Instance 0_Daily or almost daily', 'Alcohol intake frequency. | Instance 0_Never', 'Alcohol intake frequency. | Instance 0_Once or twice a week', 'Alcohol intake frequency. | Instance 0_One to three times a month', 'Alcohol intake frequency. | Instance 0_Prefer not to answer', 'Alcohol intake frequency. | Instance 0_Special occasions only', 'Alcohol intake frequency. | Instance 0_Three or four times a week', 'Bipolar and major depression status | Instance 0_Bipolar I Disorder', 'Bipolar and major depression status | Instance 0_Bipolar II Disorder', 'Bipolar and major depression status | Instance 0_No Bipolar or Depression', 'Bipolar and major depression status | Instance 0_Probable Recurrent major depression (moderate)', 'Bipolar and major depression status | Instance 0_Probable Recurrent major depression (severe)', 'Bipolar and major depression status | Instance 0_Single Probable major depression episode', 'Probable recurrent major depression (moderate) | Instance 0_Yes', 'Probable recurrent major depression (severe) | Instance 0_Yes', 'Single episode of probable major depression | Instance 0_Yes', 'Worrier / anxious feelings | Instance 0_Do not know', 'Worrier / anxious feelings | Instance 0_No', 'Worrier / anxious feelings | Instance 0_Prefer not to answer', 'Worrier / anxious feelings | Instance 0_Yes', 'Hand grip strength | Instance 0', 'Gate_speed_slow']
# 3                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         ['Age at recruitment', 'Year of birth', "Standard PRS for alzheimer's disease (AD)", 'Number in household | Instance 0', 'Has_Stroke', 'Has_High_blood_pressure', 'Sleep duration | Instance 0', 'Mean time to correctly identify matches | Instance 0', 'Fluid intelligence score | Instance 0', 'C-reactive protein | Instance 0', 'Alcohol drinker status | Instance 0_Previous', 'Alcohol intake frequency. | Instance 0_Daily or almost daily', 'Bipolar and major depression status | Instance 0_Single Probable major depression episode', 'Gate_speed_slow']
# 4                                                                                                                                                                                                                                                                                                                                                                                                                               ['Age at recruitment', 'Year of birth', "Standard PRS for alzheimer's disease (AD)", 'Townsend deprivation index at recruitment', 'Number in household | Instance 0', 'Has_Heart_attack', 'Has_Angina', 'Has_Stroke', 'Has_High_blood_pressure', 'Has_Any_Vascular_Heart_Problem', 'Sleep duration | Instance 0', 'Number of days/week of vigorous physical activity 10+ minutes | Instance 0', 'Number of days/week of moderate physical activity 10+ minutes | Instance 0', 'Mean time to correctly identify matches | Instance 0', 'Fluid intelligence score | Instance 0', 'Cholesterol | Instance 0', 'Triglycerides | Instance 0', 'C-reactive protein | Instance 0', 'Glucose | Instance 0', 'Glycated haemoglobin (HbA1c) | Instance 0', 'Creatinine | Instance 0', 'Computed_RSA_ln_ms2_Inst0', 'Average_HR_bpm_Inst0', 'Sex_Female', 'Sex_Male', 'Diabetes_Status_Do not know', 'Diabetes_Status_No', 'Diabetes_Status_Yes', 'Smoking status | Instance 0_Current', 'Smoking status | Instance 0_Never', 'Smoking status | Instance 0_Prefer not to answer', 'Smoking status | Instance 0_Previous', 'Alcohol drinker status | Instance 0_Current', 'Alcohol drinker status | Instance 0_Never', 'Alcohol drinker status | Instance 0_Prefer not to answer', 'Alcohol drinker status | Instance 0_Previous', 'Alcohol intake frequency. | Instance 0_Daily or almost daily', 'Alcohol intake frequency. | Instance 0_Never', 'Alcohol intake frequency. | Instance 0_Once or twice a week', 'Alcohol intake frequency. | Instance 0_One to three times a month', 'Alcohol intake frequency. | Instance 0_Prefer not to answer', 'Alcohol intake frequency. | Instance 0_Special occasions only', 'Alcohol intake frequency. | Instance 0_Three or four times a week', 'Bipolar and major depression status | Instance 0_Bipolar I Disorder', 'Bipolar and major depression status | Instance 0_No Bipolar or Depression', 'Bipolar and major depression status | Instance 0_Probable Recurrent major depression (moderate)', 'Bipolar and major depression status | Instance 0_Single Probable major depression episode', 'Probable recurrent major depression (severe) | Instance 0_Yes', 'Single episode of probable major depression | Instance 0_Yes', 'Worrier / anxious feelings | Instance 0_Do not know', 'Worrier / anxious feelings | Instance 0_No', 'Worrier / anxious feelings | Instance 0_Prefer not to answer', 'Worrier / anxious feelings | Instance 0_Yes', 'Hand grip strength | Instance 0', 'Gate_speed_slow']
# 5                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      ['Age at recruitment', 'Year of birth', "Standard PRS for alzheimer's disease (AD)", 'Number in household | Instance 0', 'Has_Heart_attack', 'Has_Angina', 'Has_Stroke', 'Has_High_blood_pressure', 'Mean time to correctly identify matches | Instance 0', 'Fluid intelligence score | Instance 0', 'Triglycerides | Instance 0', 'C-reactive protein | Instance 0', 'Glucose | Instance 0', 'Average_HR_bpm_Inst0', 'Average_RR_ms_Inst0', 'Pretest_RSA_ln_ms2_Inst0', 'Recovery_RSA_ln_ms2_Inst0', 'Avg_HeartPeriod_ms_Inst0', 'Diabetes_Status_Do not know', 'Diabetes_Status_No', 'Diabetes_Status_Prefer not to answer', 'Diabetes_Status_Yes', 'Smoking status | Instance 0_Never', 'Smoking status | Instance 0_Prefer not to answer', 'Smoking status | Instance 0_Previous', 'Alcohol drinker status | Instance 0_Current', 'Alcohol drinker status | Instance 0_Never', 'Alcohol drinker status | Instance 0_Previous', 'Alcohol intake frequency. | Instance 0_Never', 'Alcohol intake frequency. | Instance 0_One to three times a month', 'Alcohol intake frequency. | Instance 0_Prefer not to answer', 'Alcohol intake frequency. | Instance 0_Special occasions only', 'Alcohol intake frequency. | Instance 0_Three or four times a week', 'Bipolar and major depression status | Instance 0_Bipolar I Disorder', 'Bipolar and major depression status | Instance 0_Bipolar II Disorder', 'Bipolar and major depression status | Instance 0_No Bipolar or Depression', 'Bipolar and major depression status | Instance 0_Probable Recurrent major depression (moderate)', 'Bipolar and major depression status | Instance 0_Probable Recurrent major depression (severe)', 'Bipolar and major depression status | Instance 0_Single Probable major depression episode', 'Probable recurrent major depression (moderate) | Instance 0_Yes', 'Probable recurrent major depression (severe) | Instance 0_Yes', 'Single episode of probable major depression | Instance 0_Yes', 'Worrier / anxious feelings | Instance 0_Do not know', 'Worrier / anxious feelings | Instance 0_No', 'Worrier / anxious feelings | Instance 0_Prefer not to answer', 'Worrier / anxious feelings | Instance 0_Yes', 'Hand grip strength | Instance 0', 'Gate_speed_slow']
# 6                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      ['Age at recruitment', 'Year of birth', "Standard PRS for alzheimer's disease (AD)", 'Townsend deprivation index at recruitment', 'Has_Heart_attack', 'Has_Stroke', 'Has_High_blood_pressure', 'Sleep duration | Instance 0', 'Number of days/week of vigorous physical activity 10+ minutes | Instance 0', 'Mean time to correctly identify matches | Instance 0', 'Fluid intelligence score | Instance 0', 'Cholesterol | Instance 0', 'Creatinine | Instance 0', 'Sex_Female', 'Diabetes_Status_Do not know', 'Diabetes_Status_No', 'Smoking status | Instance 0_Current', 'Smoking status | Instance 0_Prefer not to answer', 'Alcohol drinker status | Instance 0_Current', 'Alcohol drinker status | Instance 0_Previous', 'Alcohol intake frequency. | Instance 0_Once or twice a week', 'Alcohol intake frequency. | Instance 0_One to three times a month', 'Bipolar and major depression status | Instance 0_No Bipolar or Depression', 'Single episode of probable major depression | Instance 0_Yes', 'Worrier / anxious feelings | Instance 0_Prefer not to answer', 'Hand grip strength | Instance 0', 'Gate_speed_slow']
# 7                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 ['Age at recruitment', 'Year of birth', "Standard PRS for alzheimer's disease (AD)", 'Townsend deprivation index at recruitment', 'Number in household | Instance 0', 'Has_Stroke', 'Has_High_blood_pressure', 'Has_Any_Vascular_Heart_Problem', 'Fluid intelligence score | Instance 0', 'Triglycerides | Instance 0', 'C-reactive protein | Instance 0', 'Creatinine | Instance 0', 'Average_HR_bpm_Inst0', 'Sex_Female', 'Sex_Male', 'Diabetes_Status_Do not know', 'Diabetes_Status_No', 'Diabetes_Status_Prefer not to answer', 'Smoking status | Instance 0_Current', 'Smoking status | Instance 0_Prefer not to answer', 'Alcohol intake frequency. | Instance 0_Daily or almost daily', 'Alcohol intake frequency. | Instance 0_Never', 'Alcohol intake frequency. | Instance 0_One to three times a month', 'Alcohol intake frequency. | Instance 0_Three or four times a week', 'Bipolar and major depression status | Instance 0_No Bipolar or Depression', 'Bipolar and major depression status | Instance 0_Single Probable major depression episode', 'Probable recurrent major depression (moderate) | Instance 0_Yes', 'Probable recurrent major depression (severe) | Instance 0_Yes', 'Worrier / anxious feelings | Instance 0_Do not know', 'Worrier / anxious feelings | Instance 0_No', 'Worrier / anxious feelings | Instance 0_Prefer not to answer']

# %%
import pandas as pd
from IPython.display import display

# --- show full column content ---
pd.set_option('display.max_colwidth', None)
pd.set_option('display.max_rows', None)

file_path = 'validation_results.csv'

# Load the CSV file into a pandas DataFrame
try:
    results_df = pd.read_csv(file_path)
    print("--- Validation Set Performance (Standard Scoring) ---")
    display(results_df)

except FileNotFoundError:
    print(f"Error: The file was not found at '{file_path}'")
    print("Please make sure the notebook is in the correct parent directory.")
# Out:
# --- Validation Set Performance (Standard Scoring) ---
#       Dataset    Scoring Model  Accuracy   ROC-AUC  Precision    Recall  \
# 0  Validation   accuracy   MoP  0.741007  0.791583   0.706587  0.836879
# 1  Validation   accuracy   MoE  0.708633  0.764094   0.720588  0.695035
# 2  Validation         f1   MoP  0.719424  0.780918   0.708609  0.758865
# 3  Validation         f1   MoE  0.705036  0.761402   0.668571  0.829787
# 4  Validation  precision   MoP  0.705036  0.771963   0.706294  0.716312
# 5  Validation  precision   MoE  0.683453  0.766009   0.670968  0.737589
# 6  Validation    roc_auc   MoP  0.719424  0.785215   0.708609  0.758865
# 7  Validation    roc_auc   MoE  0.679856  0.753274   0.678082  0.702128
#
#    F1 Score  Cohen Kappa  n_features  \
# 0  0.766234     0.480509          19
# 1  0.707581     0.417447          26
# 2  0.732877     0.438151          64
# 3  0.740506     0.407865          14
# 4  0.711268     0.409828          55
# 5  0.702703     0.365856          48
# 6  0.732877     0.438151          27
# 7  0.689895     0.359248          31
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       features
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               ['Age at recruitment', 'Year of birth', "Standard PRS for alzheimer's disease (AD)", 'Has_Heart_attack', 'Has_Stroke', 'Has_High_blood_pressure', 'Sleep duration | Instance 0', 'Mean time to correctly identify matches | Instance 0', 'Fluid intelligence score | Instance 0', 'Triglycerides | Instance 0', 'Creatinine | Instance 0', 'Diabetes_Status_No', 'Diabetes_Status_Yes', 'Smoking status | Instance 0_Current', 'Alcohol drinker status | Instance 0_Previous', 'Alcohol intake frequency. | Instance 0_Never', 'Bipolar and major depression status | Instance 0_No Bipolar or Depression', 'Worrier / anxious feelings | Instance 0_Prefer not to answer', 'Gate_speed_slow']
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          ['Age at recruitment', 'Year of birth', "Standard PRS for alzheimer's disease (AD)", 'Townsend deprivation index at recruitment', 'Number in household | Instance 0', 'Has_Angina', 'Has_High_blood_pressure', 'Cholesterol | Instance 0', 'Creatinine | Instance 0', 'Computed_RSA_ln_ms2_Inst0', 'Average_RR_ms_Inst0', 'Sex_Male', 'Diabetes_Status_Do not know', 'Diabetes_Status_No', 'Smoking status | Instance 0_Current', 'Smoking status | Instance 0_Prefer not to answer', 'Smoking status | Instance 0_Previous', 'Alcohol drinker status | Instance 0_Current', 'Alcohol intake frequency. | Instance 0_Never', 'Alcohol intake frequency. | Instance 0_Once or twice a week', 'Alcohol intake frequency. | Instance 0_One to three times a month', 'Alcohol intake frequency. | Instance 0_Three or four times a week', 'Bipolar and major depression status | Instance 0_Bipolar I Disorder', 'Bipolar and major depression status | Instance 0_No Bipolar or Depression', 'Worrier / anxious feelings | Instance 0_Do not know', 'Hand grip strength | Instance 0']
# 2  ['Age at recruitment', 'Year of birth', "Standard PRS for alzheimer's disease (AD)", 'Townsend deprivation index at recruitment', 'Number in household | Instance 0', 'Has_Heart_attack', 'Has_Angina', 'Has_Stroke', 'Has_High_blood_pressure', 'Has_Any_Vascular_Heart_Problem', 'Sleep duration | Instance 0', 'Number of days/week of vigorous physical activity 10+ minutes | Instance 0', 'Number of days/week of moderate physical activity 10+ minutes | Instance 0', 'Mean time to correctly identify matches | Instance 0', 'Fluid intelligence score | Instance 0', 'Cholesterol | Instance 0', 'Triglycerides | Instance 0', 'C-reactive protein | Instance 0', 'Glucose | Instance 0', 'Glycated haemoglobin (HbA1c) | Instance 0', 'Creatinine | Instance 0', 'Computed_RSA_ln_ms2_Inst0', 'Average_HR_bpm_Inst0', 'Average_RR_ms_Inst0', 'Pretest_RSA_ln_ms2_Inst0', 'Activity_RSA_ln_ms2_Inst0', 'Recovery_RSA_ln_ms2_Inst0', 'Avg_HeartPeriod_ms_Inst0', 'Sex_Female', 'Sex_Male', 'Diabetes_Status_Do not know', 'Diabetes_Status_No', 'Diabetes_Status_Prefer not to answer', 'Diabetes_Status_Yes', 'Smoking status | Instance 0_Current', 'Smoking status | Instance 0_Never', 'Smoking status | Instance 0_Prefer not to answer', 'Smoking status | Instance 0_Previous', 'Alcohol drinker status | Instance 0_Current', 'Alcohol drinker status | Instance 0_Never', 'Alcohol drinker status | Instance 0_Prefer not to answer', 'Alcohol drinker status | Instance 0_Previous', 'Alcohol intake frequency. | Instance 0_Daily or almost daily', 'Alcohol intake frequency. | Instance 0_Never', 'Alcohol intake frequency. | Instance 0_Once or twice a week', 'Alcohol intake frequency. | Instance 0_One to three times a month', 'Alcohol intake frequency. | Instance 0_Prefer not to answer', 'Alcohol intake frequency. | Instance 0_Special occasions only', 'Alcohol intake frequency. | Instance 0_Three or four times a week', 'Bipolar and major depression status | Instance 0_Bipolar I Disorder', 'Bipolar and major depression status | Instance 0_Bipolar II Disorder', 'Bipolar and major depression status | Instance 0_No Bipolar or Depression', 'Bipolar and major depression status | Instance 0_Probable Recurrent major depression (moderate)', 'Bipolar and major depression status | Instance 0_Probable Recurrent major depression (severe)', 'Bipolar and major depression status | Instance 0_Single Probable major depression episode', 'Probable recurrent major depression (moderate) | Instance 0_Yes', 'Probable recurrent major depression (severe) | Instance 0_Yes', 'Single episode of probable major depression | Instance 0_Yes', 'Worrier / anxious feelings | Instance 0_Do not know', 'Worrier / anxious feelings | Instance 0_No', 'Worrier / anxious feelings | Instance 0_Prefer not to answer', 'Worrier / anxious feelings | Instance 0_Yes', 'Hand grip strength | Instance 0', 'Gate_speed_slow']
# 3                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         ['Age at recruitment', 'Year of birth', "Standard PRS for alzheimer's disease (AD)", 'Number in household | Instance 0', 'Has_Stroke', 'Has_High_blood_pressure', 'Sleep duration | Instance 0', 'Mean time to correctly identify matches | Instance 0', 'Fluid intelligence score | Instance 0', 'C-reactive protein | Instance 0', 'Alcohol drinker status | Instance 0_Previous', 'Alcohol intake frequency. | Instance 0_Daily or almost daily', 'Bipolar and major depression status | Instance 0_Single Probable major depression episode', 'Gate_speed_slow']
# 4                                                                                                                                                                                                                                                                                                                                                                                                                               ['Age at recruitment', 'Year of birth', "Standard PRS for alzheimer's disease (AD)", 'Townsend deprivation index at recruitment', 'Number in household | Instance 0', 'Has_Heart_attack', 'Has_Angina', 'Has_Stroke', 'Has_High_blood_pressure', 'Has_Any_Vascular_Heart_Problem', 'Sleep duration | Instance 0', 'Number of days/week of vigorous physical activity 10+ minutes | Instance 0', 'Number of days/week of moderate physical activity 10+ minutes | Instance 0', 'Mean time to correctly identify matches | Instance 0', 'Fluid intelligence score | Instance 0', 'Cholesterol | Instance 0', 'Triglycerides | Instance 0', 'C-reactive protein | Instance 0', 'Glucose | Instance 0', 'Glycated haemoglobin (HbA1c) | Instance 0', 'Creatinine | Instance 0', 'Computed_RSA_ln_ms2_Inst0', 'Average_HR_bpm_Inst0', 'Sex_Female', 'Sex_Male', 'Diabetes_Status_Do not know', 'Diabetes_Status_No', 'Diabetes_Status_Yes', 'Smoking status | Instance 0_Current', 'Smoking status | Instance 0_Never', 'Smoking status | Instance 0_Prefer not to answer', 'Smoking status | Instance 0_Previous', 'Alcohol drinker status | Instance 0_Current', 'Alcohol drinker status | Instance 0_Never', 'Alcohol drinker status | Instance 0_Prefer not to answer', 'Alcohol drinker status | Instance 0_Previous', 'Alcohol intake frequency. | Instance 0_Daily or almost daily', 'Alcohol intake frequency. | Instance 0_Never', 'Alcohol intake frequency. | Instance 0_Once or twice a week', 'Alcohol intake frequency. | Instance 0_One to three times a month', 'Alcohol intake frequency. | Instance 0_Prefer not to answer', 'Alcohol intake frequency. | Instance 0_Special occasions only', 'Alcohol intake frequency. | Instance 0_Three or four times a week', 'Bipolar and major depression status | Instance 0_Bipolar I Disorder', 'Bipolar and major depression status | Instance 0_No Bipolar or Depression', 'Bipolar and major depression status | Instance 0_Probable Recurrent major depression (moderate)', 'Bipolar and major depression status | Instance 0_Single Probable major depression episode', 'Probable recurrent major depression (severe) | Instance 0_Yes', 'Single episode of probable major depression | Instance 0_Yes', 'Worrier / anxious feelings | Instance 0_Do not know', 'Worrier / anxious feelings | Instance 0_No', 'Worrier / anxious feelings | Instance 0_Prefer not to answer', 'Worrier / anxious feelings | Instance 0_Yes', 'Hand grip strength | Instance 0', 'Gate_speed_slow']
# 5                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      ['Age at recruitment', 'Year of birth', "Standard PRS for alzheimer's disease (AD)", 'Number in household | Instance 0', 'Has_Heart_attack', 'Has_Angina', 'Has_Stroke', 'Has_High_blood_pressure', 'Mean time to correctly identify matches | Instance 0', 'Fluid intelligence score | Instance 0', 'Triglycerides | Instance 0', 'C-reactive protein | Instance 0', 'Glucose | Instance 0', 'Average_HR_bpm_Inst0', 'Average_RR_ms_Inst0', 'Pretest_RSA_ln_ms2_Inst0', 'Recovery_RSA_ln_ms2_Inst0', 'Avg_HeartPeriod_ms_Inst0', 'Diabetes_Status_Do not know', 'Diabetes_Status_No', 'Diabetes_Status_Prefer not to answer', 'Diabetes_Status_Yes', 'Smoking status | Instance 0_Never', 'Smoking status | Instance 0_Prefer not to answer', 'Smoking status | Instance 0_Previous', 'Alcohol drinker status | Instance 0_Current', 'Alcohol drinker status | Instance 0_Never', 'Alcohol drinker status | Instance 0_Previous', 'Alcohol intake frequency. | Instance 0_Never', 'Alcohol intake frequency. | Instance 0_One to three times a month', 'Alcohol intake frequency. | Instance 0_Prefer not to answer', 'Alcohol intake frequency. | Instance 0_Special occasions only', 'Alcohol intake frequency. | Instance 0_Three or four times a week', 'Bipolar and major depression status | Instance 0_Bipolar I Disorder', 'Bipolar and major depression status | Instance 0_Bipolar II Disorder', 'Bipolar and major depression status | Instance 0_No Bipolar or Depression', 'Bipolar and major depression status | Instance 0_Probable Recurrent major depression (moderate)', 'Bipolar and major depression status | Instance 0_Probable Recurrent major depression (severe)', 'Bipolar and major depression status | Instance 0_Single Probable major depression episode', 'Probable recurrent major depression (moderate) | Instance 0_Yes', 'Probable recurrent major depression (severe) | Instance 0_Yes', 'Single episode of probable major depression | Instance 0_Yes', 'Worrier / anxious feelings | Instance 0_Do not know', 'Worrier / anxious feelings | Instance 0_No', 'Worrier / anxious feelings | Instance 0_Prefer not to answer', 'Worrier / anxious feelings | Instance 0_Yes', 'Hand grip strength | Instance 0', 'Gate_speed_slow']
# 6                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      ['Age at recruitment', 'Year of birth', "Standard PRS for alzheimer's disease (AD)", 'Townsend deprivation index at recruitment', 'Has_Heart_attack', 'Has_Stroke', 'Has_High_blood_pressure', 'Sleep duration | Instance 0', 'Number of days/week of vigorous physical activity 10+ minutes | Instance 0', 'Mean time to correctly identify matches | Instance 0', 'Fluid intelligence score | Instance 0', 'Cholesterol | Instance 0', 'Creatinine | Instance 0', 'Sex_Female', 'Diabetes_Status_Do not know', 'Diabetes_Status_No', 'Smoking status | Instance 0_Current', 'Smoking status | Instance 0_Prefer not to answer', 'Alcohol drinker status | Instance 0_Current', 'Alcohol drinker status | Instance 0_Previous', 'Alcohol intake frequency. | Instance 0_Once or twice a week', 'Alcohol intake frequency. | Instance 0_One to three times a month', 'Bipolar and major depression status | Instance 0_No Bipolar or Depression', 'Single episode of probable major depression | Instance 0_Yes', 'Worrier / anxious feelings | Instance 0_Prefer not to answer', 'Hand grip strength | Instance 0', 'Gate_speed_slow']
# 7                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 ['Age at recruitment', 'Year of birth', "Standard PRS for alzheimer's disease (AD)", 'Townsend deprivation index at recruitment', 'Number in household | Instance 0', 'Has_Stroke', 'Has_High_blood_pressure', 'Has_Any_Vascular_Heart_Problem', 'Fluid intelligence score | Instance 0', 'Triglycerides | Instance 0', 'C-reactive protein | Instance 0', 'Creatinine | Instance 0', 'Average_HR_bpm_Inst0', 'Sex_Female', 'Sex_Male', 'Diabetes_Status_Do not know', 'Diabetes_Status_No', 'Diabetes_Status_Prefer not to answer', 'Smoking status | Instance 0_Current', 'Smoking status | Instance 0_Prefer not to answer', 'Alcohol intake frequency. | Instance 0_Daily or almost daily', 'Alcohol intake frequency. | Instance 0_Never', 'Alcohol intake frequency. | Instance 0_One to three times a month', 'Alcohol intake frequency. | Instance 0_Three or four times a week', 'Bipolar and major depression status | Instance 0_No Bipolar or Depression', 'Bipolar and major depression status | Instance 0_Single Probable major depression episode', 'Probable recurrent major depression (moderate) | Instance 0_Yes', 'Probable recurrent major depression (severe) | Instance 0_Yes', 'Worrier / anxious feelings | Instance 0_Do not know', 'Worrier / anxious feelings | Instance 0_No', 'Worrier / anxious feelings | Instance 0_Prefer not to answer']

# %%
import pandas as pd
from IPython.display import display

# --- show full column content ---
pd.set_option('display.max_colwidth', None)
pd.set_option('display.max_rows', None)

file_path = 'train_results.csv'

# Load the CSV file into a pandas DataFrame
try:
    results_df = pd.read_csv(file_path)
    print("--- Train Set Performance (Standard Scoring) ---")
    display(results_df)

except FileNotFoundError:
    print(f"Error: The file was not found at '{file_path}'")
    print("Please make sure the notebook is in the correct parent directory.")
# Out:
# --- Train Set Performance (Standard Scoring) ---
#   Dataset    Scoring Model  Accuracy   ROC-AUC  Precision    Recall  F1 Score  \
# 0   Train   accuracy   MoP  0.754048  0.846343   0.717419  0.847561  0.777079
# 1   Train   accuracy   MoE  0.807247  0.895614   0.817187  0.797256  0.807099
# 2   Train         f1   MoP  0.801079  0.881165   0.781073  0.842988  0.810850
# 3   Train         f1   MoE  0.785659  0.874132   0.746736  0.871951  0.804501
# 4   Train  precision   MoP  0.801079  0.875059   0.792647  0.821646  0.806886
# 5   Train  precision   MoE  0.842714  0.928104   0.808743  0.902439  0.853026
# 6   Train    roc_auc   MoP  0.781804  0.873178   0.774669  0.801829  0.788015
# 7   Train    roc_auc   MoE  0.841172  0.917695   0.821429  0.876524  0.848083
#
#    Cohen Kappa  n_features  \
# 0     0.506983          19
# 1     0.614553          26
# 2     0.601736          64
# 3     0.570418          14
# 4     0.601935          55
# 5     0.684959          48
# 6     0.563371          27
# 7     0.682052          31
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       features
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               ['Age at recruitment', 'Year of birth', "Standard PRS for alzheimer's disease (AD)", 'Has_Heart_attack', 'Has_Stroke', 'Has_High_blood_pressure', 'Sleep duration | Instance 0', 'Mean time to correctly identify matches | Instance 0', 'Fluid intelligence score | Instance 0', 'Triglycerides | Instance 0', 'Creatinine | Instance 0', 'Diabetes_Status_No', 'Diabetes_Status_Yes', 'Smoking status | Instance 0_Current', 'Alcohol drinker status | Instance 0_Previous', 'Alcohol intake frequency. | Instance 0_Never', 'Bipolar and major depression status | Instance 0_No Bipolar or Depression', 'Worrier / anxious feelings | Instance 0_Prefer not to answer', 'Gate_speed_slow']
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          ['Age at recruitment', 'Year of birth', "Standard PRS for alzheimer's disease (AD)", 'Townsend deprivation index at recruitment', 'Number in household | Instance 0', 'Has_Angina', 'Has_High_blood_pressure', 'Cholesterol | Instance 0', 'Creatinine | Instance 0', 'Computed_RSA_ln_ms2_Inst0', 'Average_RR_ms_Inst0', 'Sex_Male', 'Diabetes_Status_Do not know', 'Diabetes_Status_No', 'Smoking status | Instance 0_Current', 'Smoking status | Instance 0_Prefer not to answer', 'Smoking status | Instance 0_Previous', 'Alcohol drinker status | Instance 0_Current', 'Alcohol intake frequency. | Instance 0_Never', 'Alcohol intake frequency. | Instance 0_Once or twice a week', 'Alcohol intake frequency. | Instance 0_One to three times a month', 'Alcohol intake frequency. | Instance 0_Three or four times a week', 'Bipolar and major depression status | Instance 0_Bipolar I Disorder', 'Bipolar and major depression status | Instance 0_No Bipolar or Depression', 'Worrier / anxious feelings | Instance 0_Do not know', 'Hand grip strength | Instance 0']
# 2  ['Age at recruitment', 'Year of birth', "Standard PRS for alzheimer's disease (AD)", 'Townsend deprivation index at recruitment', 'Number in household | Instance 0', 'Has_Heart_attack', 'Has_Angina', 'Has_Stroke', 'Has_High_blood_pressure', 'Has_Any_Vascular_Heart_Problem', 'Sleep duration | Instance 0', 'Number of days/week of vigorous physical activity 10+ minutes | Instance 0', 'Number of days/week of moderate physical activity 10+ minutes | Instance 0', 'Mean time to correctly identify matches | Instance 0', 'Fluid intelligence score | Instance 0', 'Cholesterol | Instance 0', 'Triglycerides | Instance 0', 'C-reactive protein | Instance 0', 'Glucose | Instance 0', 'Glycated haemoglobin (HbA1c) | Instance 0', 'Creatinine | Instance 0', 'Computed_RSA_ln_ms2_Inst0', 'Average_HR_bpm_Inst0', 'Average_RR_ms_Inst0', 'Pretest_RSA_ln_ms2_Inst0', 'Activity_RSA_ln_ms2_Inst0', 'Recovery_RSA_ln_ms2_Inst0', 'Avg_HeartPeriod_ms_Inst0', 'Sex_Female', 'Sex_Male', 'Diabetes_Status_Do not know', 'Diabetes_Status_No', 'Diabetes_Status_Prefer not to answer', 'Diabetes_Status_Yes', 'Smoking status | Instance 0_Current', 'Smoking status | Instance 0_Never', 'Smoking status | Instance 0_Prefer not to answer', 'Smoking status | Instance 0_Previous', 'Alcohol drinker status | Instance 0_Current', 'Alcohol drinker status | Instance 0_Never', 'Alcohol drinker status | Instance 0_Prefer not to answer', 'Alcohol drinker status | Instance 0_Previous', 'Alcohol intake frequency. | Instance 0_Daily or almost daily', 'Alcohol intake frequency. | Instance 0_Never', 'Alcohol intake frequency. | Instance 0_Once or twice a week', 'Alcohol intake frequency. | Instance 0_One to three times a month', 'Alcohol intake frequency. | Instance 0_Prefer not to answer', 'Alcohol intake frequency. | Instance 0_Special occasions only', 'Alcohol intake frequency. | Instance 0_Three or four times a week', 'Bipolar and major depression status | Instance 0_Bipolar I Disorder', 'Bipolar and major depression status | Instance 0_Bipolar II Disorder', 'Bipolar and major depression status | Instance 0_No Bipolar or Depression', 'Bipolar and major depression status | Instance 0_Probable Recurrent major depression (moderate)', 'Bipolar and major depression status | Instance 0_Probable Recurrent major depression (severe)', 'Bipolar and major depression status | Instance 0_Single Probable major depression episode', 'Probable recurrent major depression (moderate) | Instance 0_Yes', 'Probable recurrent major depression (severe) | Instance 0_Yes', 'Single episode of probable major depression | Instance 0_Yes', 'Worrier / anxious feelings | Instance 0_Do not know', 'Worrier / anxious feelings | Instance 0_No', 'Worrier / anxious feelings | Instance 0_Prefer not to answer', 'Worrier / anxious feelings | Instance 0_Yes', 'Hand grip strength | Instance 0', 'Gate_speed_slow']
# 3                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         ['Age at recruitment', 'Year of birth', "Standard PRS for alzheimer's disease (AD)", 'Number in household | Instance 0', 'Has_Stroke', 'Has_High_blood_pressure', 'Sleep duration | Instance 0', 'Mean time to correctly identify matches | Instance 0', 'Fluid intelligence score | Instance 0', 'C-reactive protein | Instance 0', 'Alcohol drinker status | Instance 0_Previous', 'Alcohol intake frequency. | Instance 0_Daily or almost daily', 'Bipolar and major depression status | Instance 0_Single Probable major depression episode', 'Gate_speed_slow']
# 4                                                                                                                                                                                                                                                                                                                                                                                                                               ['Age at recruitment', 'Year of birth', "Standard PRS for alzheimer's disease (AD)", 'Townsend deprivation index at recruitment', 'Number in household | Instance 0', 'Has_Heart_attack', 'Has_Angina', 'Has_Stroke', 'Has_High_blood_pressure', 'Has_Any_Vascular_Heart_Problem', 'Sleep duration | Instance 0', 'Number of days/week of vigorous physical activity 10+ minutes | Instance 0', 'Number of days/week of moderate physical activity 10+ minutes | Instance 0', 'Mean time to correctly identify matches | Instance 0', 'Fluid intelligence score | Instance 0', 'Cholesterol | Instance 0', 'Triglycerides | Instance 0', 'C-reactive protein | Instance 0', 'Glucose | Instance 0', 'Glycated haemoglobin (HbA1c) | Instance 0', 'Creatinine | Instance 0', 'Computed_RSA_ln_ms2_Inst0', 'Average_HR_bpm_Inst0', 'Sex_Female', 'Sex_Male', 'Diabetes_Status_Do not know', 'Diabetes_Status_No', 'Diabetes_Status_Yes', 'Smoking status | Instance 0_Current', 'Smoking status | Instance 0_Never', 'Smoking status | Instance 0_Prefer not to answer', 'Smoking status | Instance 0_Previous', 'Alcohol drinker status | Instance 0_Current', 'Alcohol drinker status | Instance 0_Never', 'Alcohol drinker status | Instance 0_Prefer not to answer', 'Alcohol drinker status | Instance 0_Previous', 'Alcohol intake frequency. | Instance 0_Daily or almost daily', 'Alcohol intake frequency. | Instance 0_Never', 'Alcohol intake frequency. | Instance 0_Once or twice a week', 'Alcohol intake frequency. | Instance 0_One to three times a month', 'Alcohol intake frequency. | Instance 0_Prefer not to answer', 'Alcohol intake frequency. | Instance 0_Special occasions only', 'Alcohol intake frequency. | Instance 0_Three or four times a week', 'Bipolar and major depression status | Instance 0_Bipolar I Disorder', 'Bipolar and major depression status | Instance 0_No Bipolar or Depression', 'Bipolar and major depression status | Instance 0_Probable Recurrent major depression (moderate)', 'Bipolar and major depression status | Instance 0_Single Probable major depression episode', 'Probable recurrent major depression (severe) | Instance 0_Yes', 'Single episode of probable major depression | Instance 0_Yes', 'Worrier / anxious feelings | Instance 0_Do not know', 'Worrier / anxious feelings | Instance 0_No', 'Worrier / anxious feelings | Instance 0_Prefer not to answer', 'Worrier / anxious feelings | Instance 0_Yes', 'Hand grip strength | Instance 0', 'Gate_speed_slow']
# 5                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      ['Age at recruitment', 'Year of birth', "Standard PRS for alzheimer's disease (AD)", 'Number in household | Instance 0', 'Has_Heart_attack', 'Has_Angina', 'Has_Stroke', 'Has_High_blood_pressure', 'Mean time to correctly identify matches | Instance 0', 'Fluid intelligence score | Instance 0', 'Triglycerides | Instance 0', 'C-reactive protein | Instance 0', 'Glucose | Instance 0', 'Average_HR_bpm_Inst0', 'Average_RR_ms_Inst0', 'Pretest_RSA_ln_ms2_Inst0', 'Recovery_RSA_ln_ms2_Inst0', 'Avg_HeartPeriod_ms_Inst0', 'Diabetes_Status_Do not know', 'Diabetes_Status_No', 'Diabetes_Status_Prefer not to answer', 'Diabetes_Status_Yes', 'Smoking status | Instance 0_Never', 'Smoking status | Instance 0_Prefer not to answer', 'Smoking status | Instance 0_Previous', 'Alcohol drinker status | Instance 0_Current', 'Alcohol drinker status | Instance 0_Never', 'Alcohol drinker status | Instance 0_Previous', 'Alcohol intake frequency. | Instance 0_Never', 'Alcohol intake frequency. | Instance 0_One to three times a month', 'Alcohol intake frequency. | Instance 0_Prefer not to answer', 'Alcohol intake frequency. | Instance 0_Special occasions only', 'Alcohol intake frequency. | Instance 0_Three or four times a week', 'Bipolar and major depression status | Instance 0_Bipolar I Disorder', 'Bipolar and major depression status | Instance 0_Bipolar II Disorder', 'Bipolar and major depression status | Instance 0_No Bipolar or Depression', 'Bipolar and major depression status | Instance 0_Probable Recurrent major depression (moderate)', 'Bipolar and major depression status | Instance 0_Probable Recurrent major depression (severe)', 'Bipolar and major depression status | Instance 0_Single Probable major depression episode', 'Probable recurrent major depression (moderate) | Instance 0_Yes', 'Probable recurrent major depression (severe) | Instance 0_Yes', 'Single episode of probable major depression | Instance 0_Yes', 'Worrier / anxious feelings | Instance 0_Do not know', 'Worrier / anxious feelings | Instance 0_No', 'Worrier / anxious feelings | Instance 0_Prefer not to answer', 'Worrier / anxious feelings | Instance 0_Yes', 'Hand grip strength | Instance 0', 'Gate_speed_slow']
# 6                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      ['Age at recruitment', 'Year of birth', "Standard PRS for alzheimer's disease (AD)", 'Townsend deprivation index at recruitment', 'Has_Heart_attack', 'Has_Stroke', 'Has_High_blood_pressure', 'Sleep duration | Instance 0', 'Number of days/week of vigorous physical activity 10+ minutes | Instance 0', 'Mean time to correctly identify matches | Instance 0', 'Fluid intelligence score | Instance 0', 'Cholesterol | Instance 0', 'Creatinine | Instance 0', 'Sex_Female', 'Diabetes_Status_Do not know', 'Diabetes_Status_No', 'Smoking status | Instance 0_Current', 'Smoking status | Instance 0_Prefer not to answer', 'Alcohol drinker status | Instance 0_Current', 'Alcohol drinker status | Instance 0_Previous', 'Alcohol intake frequency. | Instance 0_Once or twice a week', 'Alcohol intake frequency. | Instance 0_One to three times a month', 'Bipolar and major depression status | Instance 0_No Bipolar or Depression', 'Single episode of probable major depression | Instance 0_Yes', 'Worrier / anxious feelings | Instance 0_Prefer not to answer', 'Hand grip strength | Instance 0', 'Gate_speed_slow']
# 7                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 ['Age at recruitment', 'Year of birth', "Standard PRS for alzheimer's disease (AD)", 'Townsend deprivation index at recruitment', 'Number in household | Instance 0', 'Has_Stroke', 'Has_High_blood_pressure', 'Has_Any_Vascular_Heart_Problem', 'Fluid intelligence score | Instance 0', 'Triglycerides | Instance 0', 'C-reactive protein | Instance 0', 'Creatinine | Instance 0', 'Average_HR_bpm_Inst0', 'Sex_Female', 'Sex_Male', 'Diabetes_Status_Do not know', 'Diabetes_Status_No', 'Diabetes_Status_Prefer not to answer', 'Smoking status | Instance 0_Current', 'Smoking status | Instance 0_Prefer not to answer', 'Alcohol intake frequency. | Instance 0_Daily or almost daily', 'Alcohol intake frequency. | Instance 0_Never', 'Alcohol intake frequency. | Instance 0_One to three times a month', 'Alcohol intake frequency. | Instance 0_Three or four times a week', 'Bipolar and major depression status | Instance 0_No Bipolar or Depression', 'Bipolar and major depression status | Instance 0_Single Probable major depression episode', 'Probable recurrent major depression (moderate) | Instance 0_Yes', 'Probable recurrent major depression (severe) | Instance 0_Yes', 'Worrier / anxious feelings | Instance 0_Do not know', 'Worrier / anxious feelings | Instance 0_No', 'Worrier / anxious feelings | Instance 0_Prefer not to answer']
