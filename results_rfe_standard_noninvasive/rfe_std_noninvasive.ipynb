# %%
import pandas as pd
from IPython.display import display

# --- show full column content ---
pd.set_option('display.max_colwidth', None)
pd.set_option('display.max_rows', None)

file_path = 'test_results.csv'

# Load the CSV file into a pandas DataFrame
try:
    results_df = pd.read_csv(file_path)
    print("--- Test Set Performance (Standard Scoring) ---")
    display(results_df)

except FileNotFoundError:
    print(f"Error: The file was not found at '{file_path}'")
    print("Please make sure the notebook is in the correct parent directory.")

#0 is the best MoP
#3 is the best MoE
# Out:
# --- Test Set Performance (Standard Scoring) ---
#   Dataset    Scoring Model  Accuracy   ROC-AUC  Precision    Recall  F1 Score  \
# 0    Test   accuracy   MoP  0.737410  0.806082   0.721854  0.778571  0.749141
# 1    Test   accuracy   MoE  0.701439  0.791667   0.702128  0.707143  0.704626
# 2    Test         f1   MoP  0.730216  0.774017   0.696970  0.821429  0.754098
# 3    Test         f1   MoE  0.726619  0.784783   0.690476  0.828571  0.753247
# 4    Test  precision   MoP  0.715827  0.763742   0.707483  0.742857  0.724739
# 5    Test  precision   MoE  0.715827  0.775207   0.710345  0.735714  0.722807
# 6    Test    roc_auc   MoP  0.726619  0.794125   0.707792  0.778571  0.741497
# 7    Test    roc_auc   MoE  0.712230  0.776449   0.700000  0.750000  0.724138
#
#    Cohen Kappa  n_features  \
# 0     0.474494          24
# 1     0.402816          28
# 2     0.459705          10
# 3     0.452416           9
# 4     0.431419          14
# 5     0.431478          42
# 6     0.452813          56
# 7     0.424133          18
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     features
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            ['Age at recruitment', 'Year of birth', 'Townsend deprivation index at recruitment', 'Sex_Female', 'Has_Heart_attack', 'Has_Stroke', 'Has_Any_Vascular_Heart_Problem', 'Diabetes_Status_No', 'Diabetes_Status_Yes', 'Sleep duration | Instance 0', 'Smoking status | Instance 0_Current', 'Smoking status | Instance 0_Previous', 'Alcohol drinker status | Instance 0_Previous', 'Alcohol intake frequency. | Instance 0_Never', 'Alcohol intake frequency. | Instance 0_Once or twice a week', 'Alcohol intake frequency. | Instance 0_One to three times a month', 'Alcohol intake frequency. | Instance 0_Special occasions only', 'Alcohol intake frequency. | Instance 0_Three or four times a week', 'Worrier / anxious feelings | Instance 0_No', 'Worrier / anxious feelings | Instance 0_Yes', 'Mean time to correctly identify matches | Instance 0', 'Fluid intelligence score | Instance 0', 'Hand grip strength | Instance 0', 'Gate_speed_slow']
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  ['Age at recruitment', 'Year of birth', 'Townsend deprivation index at recruitment', 'Sex_Female', 'Sex_Male', 'Has_High_blood_pressure', 'Has_Any_Vascular_Heart_Problem', 'Diabetes_Status_Do not know', 'Diabetes_Status_No', 'Sleep duration | Instance 0', 'Number of days/week of vigorous physical activity 10+ minutes | Instance 0', 'Number of days/week of moderate physical activity 10+ minutes | Instance 0', 'Smoking status | Instance 0_Never', 'Alcohol drinker status | Instance 0_Never', 'Alcohol intake frequency. | Instance 0_Never', 'Alcohol intake frequency. | Instance 0_Once or twice a week', 'Alcohol intake frequency. | Instance 0_Prefer not to answer', 'Alcohol intake frequency. | Instance 0_Three or four times a week', 'Bipolar and major depression status | Instance 0_Bipolar I Disorder', 'Bipolar and major depression status | Instance 0_No Bipolar or Depression', 'Worrier / anxious feelings | Instance 0_Do not know', 'Worrier / anxious feelings | Instance 0_No', 'Worrier / anxious feelings | Instance 0_Yes', 'Computed_RSA_ln_ms2_Inst0', 'Average_HR_bpm_Inst0', 'Pretest_RSA_ln_ms2_Inst0', 'Recovery_RSA_ln_ms2_Inst0', 'Hand grip strength | Instance 0']
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     ['Age at recruitment', 'Year of birth', 'Townsend deprivation index at recruitment', 'Has_Heart_attack', 'Has_Stroke', 'Has_High_blood_pressure', 'Diabetes_Status_No', 'Worrier / anxious feelings | Instance 0_No', 'Mean time to correctly identify matches | Instance 0', 'Fluid intelligence score | Instance 0']
# 3                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          ['Age at recruitment', 'Year of birth', 'Townsend deprivation index at recruitment', 'Sex_Male', 'Smoking status | Instance 0_Previous', 'Alcohol drinker status | Instance 0_Previous', 'Alcohol intake frequency. | Instance 0_One to three times a month', 'Bipolar and major depression status | Instance 0_Probable Recurrent major depression (moderate)', 'Bipolar and major depression status | Instance 0_Probable Recurrent major depression (severe)']
# 4                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           ['Age at recruitment', 'Year of birth', 'Townsend deprivation index at recruitment', 'Has_Heart_attack', 'Has_Stroke', 'Has_Any_Vascular_Heart_Problem', 'Diabetes_Status_No', 'Smoking status | Instance 0_Previous', 'Alcohol drinker status | Instance 0_Previous', 'Alcohol intake frequency. | Instance 0_Once or twice a week', 'Bipolar and major depression status | Instance 0_Bipolar I Disorder', 'Mean time to correctly identify matches | Instance 0', 'Fluid intelligence score | Instance 0', 'Gate_speed_slow']
# 5                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          ['Age at recruitment', 'Year of birth', 'Townsend deprivation index at recruitment', 'Sex_Female', 'Sex_Male', 'Has_Heart_attack', 'Has_Stroke', 'Has_High_blood_pressure', 'Diabetes_Status_Do not know', 'Diabetes_Status_No', 'Diabetes_Status_Prefer not to answer', 'Diabetes_Status_Yes', 'Sleep duration | Instance 0', 'Number of days/week of moderate physical activity 10+ minutes | Instance 0', 'Smoking status | Instance 0_Current', 'Smoking status | Instance 0_Never', 'Smoking status | Instance 0_Prefer not to answer', 'Smoking status | Instance 0_Previous', 'Alcohol drinker status | Instance 0_Current', 'Alcohol drinker status | Instance 0_Never', 'Alcohol drinker status | Instance 0_Prefer not to answer', 'Alcohol drinker status | Instance 0_Previous', 'Alcohol intake frequency. | Instance 0_Daily or almost daily', 'Alcohol intake frequency. | Instance 0_Once or twice a week', 'Alcohol intake frequency. | Instance 0_Prefer not to answer', 'Bipolar and major depression status | Instance 0_Bipolar I Disorder', 'Bipolar and major depression status | Instance 0_Bipolar II Disorder', 'Bipolar and major depression status | Instance 0_Probable Recurrent major depression (moderate)', 'Bipolar and major depression status | Instance 0_Probable Recurrent major depression (severe)', 'Probable recurrent major depression (moderate) | Instance 0_Yes', 'Single episode of probable major depression | Instance 0_Yes', 'Worrier / anxious feelings | Instance 0_Do not know', 'Worrier / anxious feelings | Instance 0_Yes', 'Mean time to correctly identify matches | Instance 0', 'Fluid intelligence score | Instance 0', 'Average_HR_bpm_Inst0', 'Average_RR_ms_Inst0', 'Pretest_RSA_ln_ms2_Inst0', 'Recovery_RSA_ln_ms2_Inst0', 'Avg_HeartPeriod_ms_Inst0', 'Hand grip strength | Instance 0', 'Gate_speed_slow']
# 6  ['Age at recruitment', 'Year of birth', 'Townsend deprivation index at recruitment', 'Number in household | Instance 0', 'Sex_Female', 'Sex_Male', 'Has_Heart_attack', 'Has_Angina', 'Has_Stroke', 'Has_High_blood_pressure', 'Has_Any_Vascular_Heart_Problem', 'Diabetes_Status_Do not know', 'Diabetes_Status_No', 'Diabetes_Status_Yes', 'Sleep duration | Instance 0', 'Number of days/week of vigorous physical activity 10+ minutes | Instance 0', 'Number of days/week of moderate physical activity 10+ minutes | Instance 0', 'Smoking status | Instance 0_Current', 'Smoking status | Instance 0_Never', 'Smoking status | Instance 0_Prefer not to answer', 'Smoking status | Instance 0_Previous', 'Alcohol drinker status | Instance 0_Current', 'Alcohol drinker status | Instance 0_Never', 'Alcohol drinker status | Instance 0_Prefer not to answer', 'Alcohol drinker status | Instance 0_Previous', 'Alcohol intake frequency. | Instance 0_Daily or almost daily', 'Alcohol intake frequency. | Instance 0_Never', 'Alcohol intake frequency. | Instance 0_Once or twice a week', 'Alcohol intake frequency. | Instance 0_One to three times a month', 'Alcohol intake frequency. | Instance 0_Prefer not to answer', 'Alcohol intake frequency. | Instance 0_Special occasions only', 'Alcohol intake frequency. | Instance 0_Three or four times a week', 'Bipolar and major depression status | Instance 0_Bipolar I Disorder', 'Bipolar and major depression status | Instance 0_Bipolar II Disorder', 'Bipolar and major depression status | Instance 0_No Bipolar or Depression', 'Bipolar and major depression status | Instance 0_Probable Recurrent major depression (moderate)', 'Bipolar and major depression status | Instance 0_Probable Recurrent major depression (severe)', 'Bipolar and major depression status | Instance 0_Single Probable major depression episode', 'Probable recurrent major depression (moderate) | Instance 0_Yes', 'Probable recurrent major depression (severe) | Instance 0_Yes', 'Single episode of probable major depression | Instance 0_Yes', 'Worrier / anxious feelings | Instance 0_Do not know', 'Worrier / anxious feelings | Instance 0_No', 'Worrier / anxious feelings | Instance 0_Prefer not to answer', 'Worrier / anxious feelings | Instance 0_Yes', 'Mean time to correctly identify matches | Instance 0', 'Fluid intelligence score | Instance 0', 'Computed_RSA_ln_ms2_Inst0', 'Average_HR_bpm_Inst0', 'Average_RR_ms_Inst0', 'Pretest_RSA_ln_ms2_Inst0', 'Activity_RSA_ln_ms2_Inst0', 'Recovery_RSA_ln_ms2_Inst0', 'Avg_HeartPeriod_ms_Inst0', 'Hand grip strength | Instance 0', 'Gate_speed_slow']
# 7                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          ['Age at recruitment', 'Year of birth', 'Townsend deprivation index at recruitment', 'Number in household | Instance 0', 'Sex_Female', 'Sex_Male', 'Has_Any_Vascular_Heart_Problem', 'Number of days/week of vigorous physical activity 10+ minutes | Instance 0', 'Alcohol drinker status | Instance 0_Previous', 'Alcohol intake frequency. | Instance 0_Once or twice a week', 'Alcohol intake frequency. | Instance 0_One to three times a month', 'Alcohol intake frequency. | Instance 0_Prefer not to answer', 'Alcohol intake frequency. | Instance 0_Three or four times a week', 'Bipolar and major depression status | Instance 0_No Bipolar or Depression', 'Bipolar and major depression status | Instance 0_Single Probable major depression episode', 'Average_RR_ms_Inst0', 'Hand grip strength | Instance 0', 'Gate_speed_slow']

# %%
import pandas as pd
from IPython.display import display

# --- show full column content ---
pd.set_option('display.max_colwidth', None)
pd.set_option('display.max_rows', None)

file_path = 'validation_results.csv'

# Load the CSV file into a pandas DataFrame
try:
    results_df = pd.read_csv(file_path)
    print("--- Validation Set Performance (Standard Scoring) ---")
    display(results_df)

except FileNotFoundError:
    print(f"Error: The file was not found at '{file_path}'")
    print("Please make sure the notebook is in the correct parent directory.")
# Out:
# --- Validation Set Performance (Standard Scoring) ---
#       Dataset    Scoring Model  Accuracy   ROC-AUC  Precision    Recall  \
# 0  Validation   accuracy   MoP  0.687050  0.749185   0.658824  0.794326
# 1  Validation   accuracy   MoE  0.629496  0.719936   0.635714  0.631206
# 2  Validation         f1   MoP  0.683453  0.758555   0.656805  0.787234
# 3  Validation         f1   MoE  0.679856  0.743076   0.647727  0.808511
# 4  Validation  precision   MoP  0.701439  0.764197   0.676829  0.787234
# 5  Validation  precision   MoE  0.669065  0.725268   0.652174  0.744681
# 6  Validation    roc_auc   MoP  0.719424  0.770565   0.695652  0.794326
# 7  Validation    roc_auc   MoE  0.694245  0.739504   0.689189  0.723404
#
#    F1 Score  Cohen Kappa  n_features  \
# 0  0.720257     0.372086          24
# 1  0.633452     0.258916          28
# 2  0.716129     0.364934          10
# 3  0.719243     0.357250           9
# 4  0.727869     0.401328          14
# 5  0.695364     0.336619          42
# 6  0.741722     0.437568          56
# 7  0.705882     0.387919          18
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     features
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            ['Age at recruitment', 'Year of birth', 'Townsend deprivation index at recruitment', 'Sex_Female', 'Has_Heart_attack', 'Has_Stroke', 'Has_Any_Vascular_Heart_Problem', 'Diabetes_Status_No', 'Diabetes_Status_Yes', 'Sleep duration | Instance 0', 'Smoking status | Instance 0_Current', 'Smoking status | Instance 0_Previous', 'Alcohol drinker status | Instance 0_Previous', 'Alcohol intake frequency. | Instance 0_Never', 'Alcohol intake frequency. | Instance 0_Once or twice a week', 'Alcohol intake frequency. | Instance 0_One to three times a month', 'Alcohol intake frequency. | Instance 0_Special occasions only', 'Alcohol intake frequency. | Instance 0_Three or four times a week', 'Worrier / anxious feelings | Instance 0_No', 'Worrier / anxious feelings | Instance 0_Yes', 'Mean time to correctly identify matches | Instance 0', 'Fluid intelligence score | Instance 0', 'Hand grip strength | Instance 0', 'Gate_speed_slow']
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  ['Age at recruitment', 'Year of birth', 'Townsend deprivation index at recruitment', 'Sex_Female', 'Sex_Male', 'Has_High_blood_pressure', 'Has_Any_Vascular_Heart_Problem', 'Diabetes_Status_Do not know', 'Diabetes_Status_No', 'Sleep duration | Instance 0', 'Number of days/week of vigorous physical activity 10+ minutes | Instance 0', 'Number of days/week of moderate physical activity 10+ minutes | Instance 0', 'Smoking status | Instance 0_Never', 'Alcohol drinker status | Instance 0_Never', 'Alcohol intake frequency. | Instance 0_Never', 'Alcohol intake frequency. | Instance 0_Once or twice a week', 'Alcohol intake frequency. | Instance 0_Prefer not to answer', 'Alcohol intake frequency. | Instance 0_Three or four times a week', 'Bipolar and major depression status | Instance 0_Bipolar I Disorder', 'Bipolar and major depression status | Instance 0_No Bipolar or Depression', 'Worrier / anxious feelings | Instance 0_Do not know', 'Worrier / anxious feelings | Instance 0_No', 'Worrier / anxious feelings | Instance 0_Yes', 'Computed_RSA_ln_ms2_Inst0', 'Average_HR_bpm_Inst0', 'Pretest_RSA_ln_ms2_Inst0', 'Recovery_RSA_ln_ms2_Inst0', 'Hand grip strength | Instance 0']
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     ['Age at recruitment', 'Year of birth', 'Townsend deprivation index at recruitment', 'Has_Heart_attack', 'Has_Stroke', 'Has_High_blood_pressure', 'Diabetes_Status_No', 'Worrier / anxious feelings | Instance 0_No', 'Mean time to correctly identify matches | Instance 0', 'Fluid intelligence score | Instance 0']
# 3                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          ['Age at recruitment', 'Year of birth', 'Townsend deprivation index at recruitment', 'Sex_Male', 'Smoking status | Instance 0_Previous', 'Alcohol drinker status | Instance 0_Previous', 'Alcohol intake frequency. | Instance 0_One to three times a month', 'Bipolar and major depression status | Instance 0_Probable Recurrent major depression (moderate)', 'Bipolar and major depression status | Instance 0_Probable Recurrent major depression (severe)']
# 4                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           ['Age at recruitment', 'Year of birth', 'Townsend deprivation index at recruitment', 'Has_Heart_attack', 'Has_Stroke', 'Has_Any_Vascular_Heart_Problem', 'Diabetes_Status_No', 'Smoking status | Instance 0_Previous', 'Alcohol drinker status | Instance 0_Previous', 'Alcohol intake frequency. | Instance 0_Once or twice a week', 'Bipolar and major depression status | Instance 0_Bipolar I Disorder', 'Mean time to correctly identify matches | Instance 0', 'Fluid intelligence score | Instance 0', 'Gate_speed_slow']
# 5                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          ['Age at recruitment', 'Year of birth', 'Townsend deprivation index at recruitment', 'Sex_Female', 'Sex_Male', 'Has_Heart_attack', 'Has_Stroke', 'Has_High_blood_pressure', 'Diabetes_Status_Do not know', 'Diabetes_Status_No', 'Diabetes_Status_Prefer not to answer', 'Diabetes_Status_Yes', 'Sleep duration | Instance 0', 'Number of days/week of moderate physical activity 10+ minutes | Instance 0', 'Smoking status | Instance 0_Current', 'Smoking status | Instance 0_Never', 'Smoking status | Instance 0_Prefer not to answer', 'Smoking status | Instance 0_Previous', 'Alcohol drinker status | Instance 0_Current', 'Alcohol drinker status | Instance 0_Never', 'Alcohol drinker status | Instance 0_Prefer not to answer', 'Alcohol drinker status | Instance 0_Previous', 'Alcohol intake frequency. | Instance 0_Daily or almost daily', 'Alcohol intake frequency. | Instance 0_Once or twice a week', 'Alcohol intake frequency. | Instance 0_Prefer not to answer', 'Bipolar and major depression status | Instance 0_Bipolar I Disorder', 'Bipolar and major depression status | Instance 0_Bipolar II Disorder', 'Bipolar and major depression status | Instance 0_Probable Recurrent major depression (moderate)', 'Bipolar and major depression status | Instance 0_Probable Recurrent major depression (severe)', 'Probable recurrent major depression (moderate) | Instance 0_Yes', 'Single episode of probable major depression | Instance 0_Yes', 'Worrier / anxious feelings | Instance 0_Do not know', 'Worrier / anxious feelings | Instance 0_Yes', 'Mean time to correctly identify matches | Instance 0', 'Fluid intelligence score | Instance 0', 'Average_HR_bpm_Inst0', 'Average_RR_ms_Inst0', 'Pretest_RSA_ln_ms2_Inst0', 'Recovery_RSA_ln_ms2_Inst0', 'Avg_HeartPeriod_ms_Inst0', 'Hand grip strength | Instance 0', 'Gate_speed_slow']
# 6  ['Age at recruitment', 'Year of birth', 'Townsend deprivation index at recruitment', 'Number in household | Instance 0', 'Sex_Female', 'Sex_Male', 'Has_Heart_attack', 'Has_Angina', 'Has_Stroke', 'Has_High_blood_pressure', 'Has_Any_Vascular_Heart_Problem', 'Diabetes_Status_Do not know', 'Diabetes_Status_No', 'Diabetes_Status_Yes', 'Sleep duration | Instance 0', 'Number of days/week of vigorous physical activity 10+ minutes | Instance 0', 'Number of days/week of moderate physical activity 10+ minutes | Instance 0', 'Smoking status | Instance 0_Current', 'Smoking status | Instance 0_Never', 'Smoking status | Instance 0_Prefer not to answer', 'Smoking status | Instance 0_Previous', 'Alcohol drinker status | Instance 0_Current', 'Alcohol drinker status | Instance 0_Never', 'Alcohol drinker status | Instance 0_Prefer not to answer', 'Alcohol drinker status | Instance 0_Previous', 'Alcohol intake frequency. | Instance 0_Daily or almost daily', 'Alcohol intake frequency. | Instance 0_Never', 'Alcohol intake frequency. | Instance 0_Once or twice a week', 'Alcohol intake frequency. | Instance 0_One to three times a month', 'Alcohol intake frequency. | Instance 0_Prefer not to answer', 'Alcohol intake frequency. | Instance 0_Special occasions only', 'Alcohol intake frequency. | Instance 0_Three or four times a week', 'Bipolar and major depression status | Instance 0_Bipolar I Disorder', 'Bipolar and major depression status | Instance 0_Bipolar II Disorder', 'Bipolar and major depression status | Instance 0_No Bipolar or Depression', 'Bipolar and major depression status | Instance 0_Probable Recurrent major depression (moderate)', 'Bipolar and major depression status | Instance 0_Probable Recurrent major depression (severe)', 'Bipolar and major depression status | Instance 0_Single Probable major depression episode', 'Probable recurrent major depression (moderate) | Instance 0_Yes', 'Probable recurrent major depression (severe) | Instance 0_Yes', 'Single episode of probable major depression | Instance 0_Yes', 'Worrier / anxious feelings | Instance 0_Do not know', 'Worrier / anxious feelings | Instance 0_No', 'Worrier / anxious feelings | Instance 0_Prefer not to answer', 'Worrier / anxious feelings | Instance 0_Yes', 'Mean time to correctly identify matches | Instance 0', 'Fluid intelligence score | Instance 0', 'Computed_RSA_ln_ms2_Inst0', 'Average_HR_bpm_Inst0', 'Average_RR_ms_Inst0', 'Pretest_RSA_ln_ms2_Inst0', 'Activity_RSA_ln_ms2_Inst0', 'Recovery_RSA_ln_ms2_Inst0', 'Avg_HeartPeriod_ms_Inst0', 'Hand grip strength | Instance 0', 'Gate_speed_slow']
# 7                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          ['Age at recruitment', 'Year of birth', 'Townsend deprivation index at recruitment', 'Number in household | Instance 0', 'Sex_Female', 'Sex_Male', 'Has_Any_Vascular_Heart_Problem', 'Number of days/week of vigorous physical activity 10+ minutes | Instance 0', 'Alcohol drinker status | Instance 0_Previous', 'Alcohol intake frequency. | Instance 0_Once or twice a week', 'Alcohol intake frequency. | Instance 0_One to three times a month', 'Alcohol intake frequency. | Instance 0_Prefer not to answer', 'Alcohol intake frequency. | Instance 0_Three or four times a week', 'Bipolar and major depression status | Instance 0_No Bipolar or Depression', 'Bipolar and major depression status | Instance 0_Single Probable major depression episode', 'Average_RR_ms_Inst0', 'Hand grip strength | Instance 0', 'Gate_speed_slow']

# %%
import pandas as pd
from IPython.display import display

# --- show full column content ---
pd.set_option('display.max_colwidth', None)
pd.set_option('display.max_rows', None)

file_path = 'train_results.csv'

# Load the CSV file into a pandas DataFrame
try:
    results_df = pd.read_csv(file_path)
    print("--- Train Set Performance (Standard Scoring) ---")
    display(results_df)

except FileNotFoundError:
    print(f"Error: The file was not found at '{file_path}'")
    print("Please make sure the notebook is in the correct parent directory.")
# Out:
# --- Train Set Performance (Standard Scoring) ---
#   Dataset    Scoring Model  Accuracy   ROC-AUC  Precision    Recall  F1 Score  \
# 0   Train   accuracy   MoP  0.744025  0.837513   0.712598  0.827744  0.765867
# 1   Train   accuracy   MoE  0.800308  0.889661   0.792342  0.820122  0.805993
# 2   Train         f1   MoP  0.747880  0.817960   0.705368  0.861280  0.775566
# 3   Train         f1   MoE  0.737857  0.808699   0.700000  0.842988  0.764869
# 4   Train  precision   MoP  0.742483  0.828306   0.739583  0.757622  0.748494
# 5   Train  precision   MoE  0.818042  0.901031   0.802594  0.849085  0.825185
# 6   Train    roc_auc   MoP  0.734002  0.838347   0.727007  0.759146  0.742729
# 7   Train    roc_auc   MoE  0.768697  0.861999   0.749300  0.815549  0.781022
#
#    Cohen Kappa  n_features  \
# 0     0.487011          24
# 1     0.600399          28
# 2     0.494384          10
# 3     0.474387           9
# 4     0.484749          14
# 5     0.635788          42
# 6     0.467657          56
# 7     0.536853          18
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     features
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            ['Age at recruitment', 'Year of birth', 'Townsend deprivation index at recruitment', 'Sex_Female', 'Has_Heart_attack', 'Has_Stroke', 'Has_Any_Vascular_Heart_Problem', 'Diabetes_Status_No', 'Diabetes_Status_Yes', 'Sleep duration | Instance 0', 'Smoking status | Instance 0_Current', 'Smoking status | Instance 0_Previous', 'Alcohol drinker status | Instance 0_Previous', 'Alcohol intake frequency. | Instance 0_Never', 'Alcohol intake frequency. | Instance 0_Once or twice a week', 'Alcohol intake frequency. | Instance 0_One to three times a month', 'Alcohol intake frequency. | Instance 0_Special occasions only', 'Alcohol intake frequency. | Instance 0_Three or four times a week', 'Worrier / anxious feelings | Instance 0_No', 'Worrier / anxious feelings | Instance 0_Yes', 'Mean time to correctly identify matches | Instance 0', 'Fluid intelligence score | Instance 0', 'Hand grip strength | Instance 0', 'Gate_speed_slow']
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  ['Age at recruitment', 'Year of birth', 'Townsend deprivation index at recruitment', 'Sex_Female', 'Sex_Male', 'Has_High_blood_pressure', 'Has_Any_Vascular_Heart_Problem', 'Diabetes_Status_Do not know', 'Diabetes_Status_No', 'Sleep duration | Instance 0', 'Number of days/week of vigorous physical activity 10+ minutes | Instance 0', 'Number of days/week of moderate physical activity 10+ minutes | Instance 0', 'Smoking status | Instance 0_Never', 'Alcohol drinker status | Instance 0_Never', 'Alcohol intake frequency. | Instance 0_Never', 'Alcohol intake frequency. | Instance 0_Once or twice a week', 'Alcohol intake frequency. | Instance 0_Prefer not to answer', 'Alcohol intake frequency. | Instance 0_Three or four times a week', 'Bipolar and major depression status | Instance 0_Bipolar I Disorder', 'Bipolar and major depression status | Instance 0_No Bipolar or Depression', 'Worrier / anxious feelings | Instance 0_Do not know', 'Worrier / anxious feelings | Instance 0_No', 'Worrier / anxious feelings | Instance 0_Yes', 'Computed_RSA_ln_ms2_Inst0', 'Average_HR_bpm_Inst0', 'Pretest_RSA_ln_ms2_Inst0', 'Recovery_RSA_ln_ms2_Inst0', 'Hand grip strength | Instance 0']
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     ['Age at recruitment', 'Year of birth', 'Townsend deprivation index at recruitment', 'Has_Heart_attack', 'Has_Stroke', 'Has_High_blood_pressure', 'Diabetes_Status_No', 'Worrier / anxious feelings | Instance 0_No', 'Mean time to correctly identify matches | Instance 0', 'Fluid intelligence score | Instance 0']
# 3                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          ['Age at recruitment', 'Year of birth', 'Townsend deprivation index at recruitment', 'Sex_Male', 'Smoking status | Instance 0_Previous', 'Alcohol drinker status | Instance 0_Previous', 'Alcohol intake frequency. | Instance 0_One to three times a month', 'Bipolar and major depression status | Instance 0_Probable Recurrent major depression (moderate)', 'Bipolar and major depression status | Instance 0_Probable Recurrent major depression (severe)']
# 4                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           ['Age at recruitment', 'Year of birth', 'Townsend deprivation index at recruitment', 'Has_Heart_attack', 'Has_Stroke', 'Has_Any_Vascular_Heart_Problem', 'Diabetes_Status_No', 'Smoking status | Instance 0_Previous', 'Alcohol drinker status | Instance 0_Previous', 'Alcohol intake frequency. | Instance 0_Once or twice a week', 'Bipolar and major depression status | Instance 0_Bipolar I Disorder', 'Mean time to correctly identify matches | Instance 0', 'Fluid intelligence score | Instance 0', 'Gate_speed_slow']
# 5                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          ['Age at recruitment', 'Year of birth', 'Townsend deprivation index at recruitment', 'Sex_Female', 'Sex_Male', 'Has_Heart_attack', 'Has_Stroke', 'Has_High_blood_pressure', 'Diabetes_Status_Do not know', 'Diabetes_Status_No', 'Diabetes_Status_Prefer not to answer', 'Diabetes_Status_Yes', 'Sleep duration | Instance 0', 'Number of days/week of moderate physical activity 10+ minutes | Instance 0', 'Smoking status | Instance 0_Current', 'Smoking status | Instance 0_Never', 'Smoking status | Instance 0_Prefer not to answer', 'Smoking status | Instance 0_Previous', 'Alcohol drinker status | Instance 0_Current', 'Alcohol drinker status | Instance 0_Never', 'Alcohol drinker status | Instance 0_Prefer not to answer', 'Alcohol drinker status | Instance 0_Previous', 'Alcohol intake frequency. | Instance 0_Daily or almost daily', 'Alcohol intake frequency. | Instance 0_Once or twice a week', 'Alcohol intake frequency. | Instance 0_Prefer not to answer', 'Bipolar and major depression status | Instance 0_Bipolar I Disorder', 'Bipolar and major depression status | Instance 0_Bipolar II Disorder', 'Bipolar and major depression status | Instance 0_Probable Recurrent major depression (moderate)', 'Bipolar and major depression status | Instance 0_Probable Recurrent major depression (severe)', 'Probable recurrent major depression (moderate) | Instance 0_Yes', 'Single episode of probable major depression | Instance 0_Yes', 'Worrier / anxious feelings | Instance 0_Do not know', 'Worrier / anxious feelings | Instance 0_Yes', 'Mean time to correctly identify matches | Instance 0', 'Fluid intelligence score | Instance 0', 'Average_HR_bpm_Inst0', 'Average_RR_ms_Inst0', 'Pretest_RSA_ln_ms2_Inst0', 'Recovery_RSA_ln_ms2_Inst0', 'Avg_HeartPeriod_ms_Inst0', 'Hand grip strength | Instance 0', 'Gate_speed_slow']
# 6  ['Age at recruitment', 'Year of birth', 'Townsend deprivation index at recruitment', 'Number in household | Instance 0', 'Sex_Female', 'Sex_Male', 'Has_Heart_attack', 'Has_Angina', 'Has_Stroke', 'Has_High_blood_pressure', 'Has_Any_Vascular_Heart_Problem', 'Diabetes_Status_Do not know', 'Diabetes_Status_No', 'Diabetes_Status_Yes', 'Sleep duration | Instance 0', 'Number of days/week of vigorous physical activity 10+ minutes | Instance 0', 'Number of days/week of moderate physical activity 10+ minutes | Instance 0', 'Smoking status | Instance 0_Current', 'Smoking status | Instance 0_Never', 'Smoking status | Instance 0_Prefer not to answer', 'Smoking status | Instance 0_Previous', 'Alcohol drinker status | Instance 0_Current', 'Alcohol drinker status | Instance 0_Never', 'Alcohol drinker status | Instance 0_Prefer not to answer', 'Alcohol drinker status | Instance 0_Previous', 'Alcohol intake frequency. | Instance 0_Daily or almost daily', 'Alcohol intake frequency. | Instance 0_Never', 'Alcohol intake frequency. | Instance 0_Once or twice a week', 'Alcohol intake frequency. | Instance 0_One to three times a month', 'Alcohol intake frequency. | Instance 0_Prefer not to answer', 'Alcohol intake frequency. | Instance 0_Special occasions only', 'Alcohol intake frequency. | Instance 0_Three or four times a week', 'Bipolar and major depression status | Instance 0_Bipolar I Disorder', 'Bipolar and major depression status | Instance 0_Bipolar II Disorder', 'Bipolar and major depression status | Instance 0_No Bipolar or Depression', 'Bipolar and major depression status | Instance 0_Probable Recurrent major depression (moderate)', 'Bipolar and major depression status | Instance 0_Probable Recurrent major depression (severe)', 'Bipolar and major depression status | Instance 0_Single Probable major depression episode', 'Probable recurrent major depression (moderate) | Instance 0_Yes', 'Probable recurrent major depression (severe) | Instance 0_Yes', 'Single episode of probable major depression | Instance 0_Yes', 'Worrier / anxious feelings | Instance 0_Do not know', 'Worrier / anxious feelings | Instance 0_No', 'Worrier / anxious feelings | Instance 0_Prefer not to answer', 'Worrier / anxious feelings | Instance 0_Yes', 'Mean time to correctly identify matches | Instance 0', 'Fluid intelligence score | Instance 0', 'Computed_RSA_ln_ms2_Inst0', 'Average_HR_bpm_Inst0', 'Average_RR_ms_Inst0', 'Pretest_RSA_ln_ms2_Inst0', 'Activity_RSA_ln_ms2_Inst0', 'Recovery_RSA_ln_ms2_Inst0', 'Avg_HeartPeriod_ms_Inst0', 'Hand grip strength | Instance 0', 'Gate_speed_slow']
# 7                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          ['Age at recruitment', 'Year of birth', 'Townsend deprivation index at recruitment', 'Number in household | Instance 0', 'Sex_Female', 'Sex_Male', 'Has_Any_Vascular_Heart_Problem', 'Number of days/week of vigorous physical activity 10+ minutes | Instance 0', 'Alcohol drinker status | Instance 0_Previous', 'Alcohol intake frequency. | Instance 0_Once or twice a week', 'Alcohol intake frequency. | Instance 0_One to three times a month', 'Alcohol intake frequency. | Instance 0_Prefer not to answer', 'Alcohol intake frequency. | Instance 0_Three or four times a week', 'Bipolar and major depression status | Instance 0_No Bipolar or Depression', 'Bipolar and major depression status | Instance 0_Single Probable major depression episode', 'Average_RR_ms_Inst0', 'Hand grip strength | Instance 0', 'Gate_speed_slow']
